# %% [markdown]
# <h1 align=center><font size = 10>Data Science Capstone Week3</font></h1>
#
#
# ## Segmenting and Clustering in Toronto Neighborhoods
# ### Kakulavaram Manoj
# ### Data Science Capstone Project week 3
#
# As part of the Week 3 submission I will be doing all the three parts of the assignment in this single notebook.
# All the sections will be marked to help  review.
#
#
# ## Section 1

# %% [markdown]
#  #### Import Libraries

# %%
import pandas as pd
import numpy as np
import requests

# %%
toronto_wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
read_toronto_wiki = requests.get(toronto_wiki)

nghbrhd_data = pd.read_html(read_toronto_wiki.content, header = 0)[0]
nghbrhd_data

# Display the raw data
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# Displaying the data with Neighborhood excluding "Not Assigned"

# %%
toronto_df = nghbrhd_data[nghbrhd_data.Neighbourhood != 'Not assigned']
toronto_df.reset_index(inplace = True)
toronto_df.head()
# Out:
#    index Postal Code           Borough  \
# 0      2         M3A        North York
# 1      3         M4A        North York
# 2      4         M5A  Downtown Toronto
# 3      5         M6A        North York
# 4      6         M7A  Downtown Toronto
#
#                                  Neighbourhood
# 0                                    Parkwoods
# 1                             Victoria Village
# 2                    Regent Park, Harbourfront
# 3             Lawrence Manor, Lawrence Heights
# 4  Queen's Park, Ontario Provincial Government

# %%
print('Shape of the Dataframe :', toronto_df.shape)
print('Unique Neighborhoods :' ,len(toronto_df['Postal Code'].unique()))
toronto_df.groupby(['Postal Code']).first()
# Out:
# Shape of the Dataframe : (103, 4)
# Unique Neighborhoods : 103
#              index      Borough  \
# Postal Code
# M1B              9  Scarborough
# M1C             18  Scarborough
# M1E             27  Scarborough
# M1G             36  Scarborough
# M1H             45  Scarborough
# ...            ...          ...
# M9N             98         York
# M9P            107    Etobicoke
# M9R            116    Etobicoke
# M9V            143    Etobicoke
# M9W            152    Etobicoke
#
#                                                  Neighbourhood
# Postal Code
# M1B                                             Malvern, Rouge
# M1C                     Rouge Hill, Port Union, Highland Creek
# M1E                          Guildwood, Morningside, West Hill
# M1G                                                     Woburn
# M1H                                                  Cedarbrae
# ...                                                        ...
# ...

# %% [markdown]
# ## Section 2
# ## GeoCoder
# This Section will use the Geocoder package to enrich the data with the lattitue and longitude details  for each postal code for Toronto.
# We will import Geocoder libraries and work through each postal code to get the required details for the data.

# %%
import geocoder

# %%
url = 'http://cocl.us/Geospatial_data'

df_geocodes=pd.read_csv(url)
df_geocodes.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
print(df_geocodes.dtypes)
print(df_geocodes.shape)
df_toronto_postal = toronto_df.join(df_geocodes.set_index('Postal Code'), on='Postal Code')
df_toronto_postal
# Out:
# Postal Code     object
# Latitude       float64
# Longitude      float64
# dtype: object
# (103, 3)
#      index Postal Code           Borough  \
# 0        2         M3A        North York
# 1        3         M4A        North York
# 2        4         M5A  Downtown Toronto
# 3        5         M6A        North York
# 4        6         M7A  Downtown Toronto
# ..     ...         ...               ...
# 98     160         M8X         Etobicoke
# 99     165         M4Y  Downtown Toronto
# 100    168         M7Y      East Toronto
# 101    169         M8Y         Etobicoke
# 102    178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# ...

# %%
df_toronto_postal = df_toronto_postal.reset_index()
df_toronto_postal.drop(['index'], axis = 'columns', inplace = True)
df_toronto_postal = df_toronto_postal.set_index('level_0')
toronto_postal_df = df_toronto_postal.rename(index = {'level_0' : 'index'})
toronto_postal_df.index.name = 'index'
print(toronto_postal_df.shape)
toronto_postal_df
# Out:
# (103, 5)
#       Postal Code           Borough  \
# index
# 0             M3A        North York
# 1             M4A        North York
# 2             M5A  Downtown Toronto
# 3             M6A        North York
# 4             M7A  Downtown Toronto
# ...           ...               ...
# 98            M8X         Etobicoke
# 99            M4Y  Downtown Toronto
# 100           M7Y      East Toronto
# 101           M8Y         Etobicoke
# 102           M8Z         Etobicoke
#
#                                            Neighbourhood   Latitude  Longitude
# index
# 0                                              Parkwoods  43.753259 -79.329656
# 1                                       Victoria Village  43.725882 -79.315572
# 2                              Regent Park, Harbourfront  43.654260 -79.360636
# 3                       Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4            Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ...

# %% [markdown]
# This is the end of Section 2. Above dataframe print shows the toronto neighborhoods data with corresponding Lattitude and longitude deetails
#
# ## Section 3
#  This is the beginning of section 3 where we will cluster the neighborhoods in Toronto.

# %%
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'YXUDU41FRIWR0M2CLK5ZXM42FSO1SFJSLB04SUA2P2KOY2OM' # your Foursquare ID
CLIENT_SECRET = 'EZTKZHOQGKSAJBROKW2IQMUY24PD2X4W0N3IQ2TT3QNS4ELC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YXUDU41FRIWR0M2CLK5ZXM42FSO1SFJSLB04SUA2P2KOY2OM
# CLIENT_SECRET:EZTKZHOQGKSAJBROKW2IQMUY24PD2X4W0N3IQ2TT3QNS4ELC

# %%
address = 'Toronto,Ontario,CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
toronto_map=folium.Map(location=[latitude ,longitude] , zoom_start=13)
toronto_map
# Out:
# 43.6534817 -79.3839347
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Boroughs_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel
#toronto_postal_df
# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(Boroughs_map)

# add the Italian restaurants as blue circle markers
for lat, lng, nghbrhd , borough in zip(toronto_postal_df.Latitude, toronto_postal_df.Longitude, toronto_postal_df.Neighbourhood , toronto_postal_df.Borough):
    label = '{}, {}'.format(nghbrhd, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(Boroughs_map)

# display map
Boroughs_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(toronto_postal_df)
first_latitude = toronto_postal_df.loc[0, 'Latitude'] # neighborhood latitude value
first_longitude = toronto_postal_df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_postal_df.loc[0, 'Neighbourhood'] # neighborhood name
LIMIT = 100
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    first_latitude, 
    first_longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()
results
# Out:
#       Postal Code           Borough  \
# index
# 0             M3A        North York
# 1             M4A        North York
# 2             M5A  Downtown Toronto
# 3             M6A        North York
# 4             M7A  Downtown Toronto
# ...           ...               ...
# 98            M8X         Etobicoke
# 99            M4Y  Downtown Toronto
# 100           M7Y      East Toronto
# 101           M8Y         Etobicoke
# 102           M8Z         Etobicoke
#
#                                            Neighbourhood   Latitude  Longitude
# index
# 0                                              Parkwoods  43.753259 -79.329656
# 1                                       Victoria Village  43.725882 -79.315572
# 2                              Regent Park, Harbourfront  43.654260 -79.360636
# 3                       Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4            Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ...
